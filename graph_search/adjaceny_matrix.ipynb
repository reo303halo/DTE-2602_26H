# %%
# Another way of representing a graph in Pyton is adjaceny matrix:
                  # A  B  C  D
adjaceny_matrix = [[0, 1, 1, 0], # A - > B, C
                   [1, 0, 0, 1], # B - > A, D
                   [1, 0, 0, 1], # C - > A, D
                   [0, 1, 1, 0]  # D - > B, C
                  ]

# A 1 means there is an edge between the two vertices; 0 means there isn't.
# This example shows the same graph as first cell in graph_demo:

# A basic adjaceny list
graph = {
    "A": ["B", "C"],
    "B": ["A", "D"],
    "C": ["A", "D"],
    "D": ["B", "C"]
}
# - also saved as a png (example_A.png) in this folder.

# %%
# Practice task 1:
#        A
#       / \
#      B---C
#       \ /
#        D

# Write the adjacency list for vertices A, B, C and D.
# Write the adjacency matrix.
# Who are the neighbors of A?
# Who are the neighbors of D?

# %%
# Practice task 2:
#        A
#       / \
#      B   C
#     / \   \
#    D---E---F

# Create an adjacency list.
# Create an adjacency matrix.
# List all neighbors of B.
# List all neighbors of E.
# How many edges does the graph contain?
