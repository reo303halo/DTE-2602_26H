# %%
# Practice task 1:
#        A
#       / \
#      B---C
#       \ /
#        D

# 1.Write the adjacency list for vertices A, B, C and D.
# 2.Write the adjacency matrix.
# 3.Who are the neighbors of A?
# 4.Who are the neighbors of D?

# 1.
adjacency_list = {
    "A": ["B", "C"],
    "B": ["A", "C", "D"],
    "C": ["A", "B", "D"],
    "D": ["B", "C"]
}


#2.
#     A  B  C  D
adjacency_matrix = [
    [0, 1, 1, 0],  # A
    [1, 0, 1, 1],  # B
    [1, 1, 0, 1],  # C
    [0, 1, 1, 0]   # D
]

#3. 
print(adjacency_list["A"]) 
# Alternativly you see adjacency_matrix[0] and see that is's got a 1 at index 1, and 2.
# Index 0 - A, index 1 - B, index 2 - C, index 3 - D

#4.
print(adjacency_list["D"])
# Out:
# ['B', 'C']
# ['B', 'C']

# %%
# Practice task 2:
#        A
#       / \
#      B   C
#     / \   \
#    D---E---F

# 1.Create an adjacency list.
# 2.Create an adjacency matrix.
# 3.List all neighbors of B.
# 4.List all neighbors of E.
# 5.How many edges does the graph contain?

#1.
adjacency_list = {
    "A": ["B", "C"],
    "B": ["A", "D", "E"],
    "C": ["A", "F"],
    "D": ["B", "E"],
    "E": ["B", "D", "F"],
    "F": ["C", "E"]
}

#2.
#     A  B  C  D  E  F
adjacency_matrix = [
    [0, 1, 1, 0, 0, 0],  # A
    [1, 0, 0, 1, 1, 0],  # B
    [1, 0, 0, 0, 0, 1],  # C
    [0, 1, 0, 0, 1, 0],  # D
    [0, 1, 0, 1, 0, 1],  # E
    [0, 0, 1, 0, 1, 0]   # F
]


#3.
print(adjacency_list["B"]) 

#4.
print(adjacency_list["E"]) 

#5.
# The graph contains 7 edges:
# A-B
# A-C
# B-D
# B-E
# D-E
# E-F
# C-F
# Out:
# ['A', 'D', 'E']
# ['B', 'D', 'F']
